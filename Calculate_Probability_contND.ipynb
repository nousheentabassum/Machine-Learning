# %%
# !pip install scipy

# %%
#p(x>= 70) ans p(x<=70)
#mean = 60
#sd = 10
from scipy import stats
# vall=stats.norm.cdf(70,loc=60,scale=10)
vall=stats.norm.cdf(70,60,10)
print(vall)
valg = 1-vall
print(valg)
# Out:
# 0.8413447460685429
# 0.15865525393145707

# %%
#p(x<= 680)
#mean = 711
#sd = 29
# for lessthan or equal to we neednot to sub form 1 as it give by default
stats.norm.cdf(680,711,29)
# Out:
# np.float64(0.14254260383881612)

# %%
#p(x>= 720)
#mean = 711
#sd = 29
# as the stats function only give u <= probability to obtain >= prop we can sub the <= prop form 1.
y=1-stats.norm.cdf(720,711,29)
y
# Out:
# np.float64(0.37814937265194704)

# %%
#p(x>= 680) & p(x>= 740)  area b/w 680 ans 740 
#mean = 711
#sd = 29
# a=stats.norm.cdf(680,711,29)
# b=stats.norm.cdf(740,711,29)
# ans = b-a
# ans
stats.norm.cdf(740,711,29)-stats.norm.cdf(680,711,29)
# Out:
# np.float64(0.6988021422297268)
