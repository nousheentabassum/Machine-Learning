# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/furkhanansari/Desktop/Data Science/DataSets/data_clean.csv')

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.tail(10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 148         149   30.0    193.0   6.9     70     9   26  2010    70       C
# 149         150    NaN    145.0  13.2     77     9   27  2010    77      PS
# 150         151   14.0    191.0  14.3     75     9   28  2010    75       S
# 151         152   18.0    131.0   8.0     76     9   29  2010    76      PS
# 152         153   20.0    223.0  11.5     68     9   30  2010    68       S
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
type(data)
data.shape
# Out:
# (158, 10)

# %%
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
#data types
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
# temp c is wronge data type
# month is also wornge datatype
# weather is also wornge datatype
# data type conversion
data['Month'] =  pd.to_numeric(data['Month'],errors='coerce')
data['Temp C'] =  pd.to_numeric(data['Temp C'],errors='coerce')
data['Weather'] = data['Weather'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       157 non-null    float64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(5), int64(4)
# memory usage: 11.5 KB

# %%
#detedting duplicate

# %%
data[data.duplicated()].shape
# Out:
# (0, 10)

# %%
# printing the duplicate row
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
# removing duplicate data
data_cleaned1 = data.drop_duplicates()

# %%
# Dropping col
data_cleaned2 = data_cleaned1.drop('Temp C' ,axis=1)

# %%
data_cleaned2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    5.0    1  2010    67       S
# 1             2   36.0    118.0   8.0    5.0    2  2010    72       C
# 2             3   12.0    149.0  12.6    5.0    3  2010    74      PS
# 3             4   18.0    313.0  11.5    5.0    4  2010    62       S
# 4             5    NaN      NaN  14.3    5.0    5  2010    56       S
# ..          ...    ...      ...   ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    5.0    1  2010    67       C
# 154         155   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155         156    NaN    145.0  13.2    9.0   27  2010    77       S
# 156         157   14.0    191.0  14.3    9.0   28  2010    75       S
# 157         158   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
# renaming the cols
data_cleaned3 = data_cleaned2.rename({'Solar.R':'Solar'},axis=1)

# %%
data_cleaned3
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4    5.0    1  2010    67       S
# 1             2   36.0  118.0   8.0    5.0    2  2010    72       C
# 2             3   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3             4   18.0  313.0  11.5    5.0    4  2010    62       S
# 4             5    NaN    NaN  14.3    5.0    5  2010    56       S
# ..          ...    ...    ...   ...    ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4    5.0    1  2010    67       C
# 154         155   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155         156    NaN  145.0  13.2    9.0   27  2010    77       S
# 156         157   14.0  191.0  14.3    9.0   28  2010    75       S
# 157         158   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
# histogram of ozone
data_cleaned3['Ozone'].hist()
# Out:
# <Axes: >

# %%
# boxplot
data_box = data_cleaned3.dropna()
data1_box = data_box.Ozone
plt.boxplot(data1_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15b5a8550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15b5a87d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15b5a8410>],
#  'medians': [<matplotlib.lines.Line2D at 0x15b5a8a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15b5a8b90>],
#  'means': []}

# %%
# Extracting outliers
box = plt.boxplot(data1_box)

# %%
[item.get_ydata() for item in box ['fliers']]  # fliers are outliers
# Out:
# [array([135., 168.])]

# %%
# to get the whiskers 
[item.get_ydata()[1] for item in box ['whiskers']]  # whiskers are are lines in boxplot
#  any value more not in b/w these two points is a outliers
# Out:
# [np.float64(1.0), np.float64(122.0)]

# %%
# Discriptive Statistics
data_cleaned3['Ozone'].describe()
# Out:
# count    120.000000
# mean      41.583333
# std       32.620709
# min        1.000000
# 25%       18.000000
# 50%       30.500000
# 75%       61.500000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
data_cleaned3
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4    5.0    1  2010    67       S
# 1             2   36.0  118.0   8.0    5.0    2  2010    72       C
# 2             3   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3             4   18.0  313.0  11.5    5.0    4  2010    62       S
# 4             5    NaN    NaN  14.3    5.0    5  2010    56       S
# ..          ...    ...    ...   ...    ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4    5.0    1  2010    67       C
# 154         155   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155         156    NaN  145.0  13.2    9.0   27  2010    77       S
# 156         157   14.0  191.0  14.3    9.0   28  2010    75       S
# 157         158   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
# bar plot
data['Weather'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Weather'>

# %%
# missing values and imputation

# %%
# generating heat map
import seaborn as sns
cols = data_cleaned3.columns
colours = ['#000099','#ffff00']  # two colors yellow is missing value ,indigo not null col 
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap= sns.color_palette(colours))
# Out:
# <Axes: >

# %%
# missing values in the dataset are generated ans top 5 missing vales are printed
data_cleaned3[data_cleaned3.isnull().any(axis=1)].head()
# Out:
#     Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4            5    NaN    NaN  14.3    5.0    5  2010    56       S
# 5            6   28.0    NaN  14.9    5.0    6  2010    66       C
# 9           10    NaN  194.0   8.6    5.0   10  2010    69       S
# 10          11    7.0    NaN   6.9    5.0   11  2010    74       C
# 23          24   32.0   92.0  12.0    NaN   24  2010    61       C

# %%
#find the number of missing value form each of the col
data_cleaned3.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar          7
# Wind           0
# Month          1
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
# mean imputation

# finding mean of the ozone col
mean = data_cleaned3['Ozone'].mean()
print(mean)
# Out:
# 41.583333333333336

# %%
#filling na values of ozone with mean of that col
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(mean)

# %%
data_cleaned3.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar         7
# Wind          0
# Month         1
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
# missing value imputaion of the categorical values
# get the object coloums
obj_columns = data_cleaned3[['Weather']]

# %%
obj_columns
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 1 columns]

# %%
obj_columns.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
obj_columns.mode()
# Out:
#   Weather
# 0       S

# %%
obj_columns.mode().iloc[0]
# Out:
# Weather    S
# Name: 0, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
# missing values impitation for categorical value
obj_columns = obj_columns.fillna(obj_columns.mode().iloc[0])

# %%
obj_columns.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
data_cleaned3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
obj_columns.shape
# Out:
# (158, 1)

# %%
# removeing the present weather col form the dataset
data_cleaned4 = data_cleaned3.drop(['Weather'],axis=1,inplace=True)

# %%
# joining the dataset wiht the imputed object dataset
data_cleaned4 = pd.concat([data_cleaned3,obj_columns],axis=1)

# %%
data_cleaned4
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data_cleaned4.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar         7
# Wind          0
# Month         1
# Day           0
# Year          0
# Temp          0
# Weather       0
# dtype: int64

# %%
# Scatter polt ans correlation analysis

# %%
# seaborn visualization library
import seaborn as sns

# crea the default pairplot
sns.pairplot(data_cleaned3)

# %%
# correlation
data_cleaned3.corr()
# Out:
#             Unnamed: 0     Ozone     Solar      Wind     Month       Day  \
# Unnamed: 0    1.000000  0.111910 -0.109520 -0.158309  0.949690  0.216219
# Ozone         0.111910  1.000000  0.307253 -0.523806  0.123962 -0.030241
# Solar        -0.109520  0.307253  1.000000 -0.056594 -0.092918 -0.154212
# Wind         -0.158309 -0.523806 -0.056594  1.000000 -0.153507  0.040151
# Month         0.949690  0.123962 -0.092918 -0.153507  1.000000  0.061236
# Day           0.216219 -0.030241 -0.154212  0.040151  0.061236  1.000000
# Year               NaN       NaN       NaN       NaN       NaN       NaN
# Temp          0.337537  0.606275  0.273322 -0.441247  0.393321 -0.124538
#
#             Year      Temp
# Unnamed: 0   NaN  0.337537
# Ozone        NaN  0.606275
# Solar        NaN  0.273322
# Wind         NaN -0.441247
# Month        NaN  0.393321
# Day          NaN -0.124538
# Year         NaN       NaN
# Temp         NaN  1.000000

# %%
data_cleaned3.Year # year is constant so NAN is given
# Out:
# 0      2010
# 1      2010
# 2      2010
# 3      2010
# 4      2010
#        ...
# 153    2010
# 154    2010
# 155    2010
# 156    2010
# 157    2010
# Name: Year, Length: 158, dtype: int64

# %%
# Transformation

# %%
# creating dummy varibales for weather coloum
data_cleaned4 = pd.get_dummies(data,columns=['Weather'])

# %%
data_cleaned4
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp  \
# 0             1   41.0    190.0   7.4    67.0    5.0    1  2010    67
# 1             2   36.0    118.0   8.0    72.0    5.0    2  2010    72
# 2             3   12.0    149.0  12.6    74.0    5.0    3  2010    74
# 3             4   18.0    313.0  11.5    62.0    5.0    4  2010    62
# 4             5    NaN      NaN  14.3    56.0    5.0    5  2010    56
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...
# 153         154   41.0    190.0   7.4    67.0    5.0    1  2010    67
# 154         155   30.0    193.0   6.9    70.0    9.0   26  2010    70
# 155         156    NaN    145.0  13.2    77.0    9.0   27  2010    77
# 156         157   14.0    191.0  14.3    75.0    9.0   28  2010    75
# 157         158   18.0    131.0   8.0    76.0    9.0   29  2010    76
#
#      Weather_C  Weather_PS  Weather_S
# 0        False       False       True
# 1         True       False      False
# ...

# %%
data_cleaned4 = data_cleaned4.dropna()

# %%
data_cleaned4
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp  \
# 0             1   41.0    190.0   7.4    67.0    5.0    1  2010    67
# 1             2   36.0    118.0   8.0    72.0    5.0    2  2010    72
# 2             3   12.0    149.0  12.6    74.0    5.0    3  2010    74
# 3             4   18.0    313.0  11.5    62.0    5.0    4  2010    62
# 6             7   23.0    299.0   8.6    65.0    5.0    7  2010    65
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...
# 152         153   20.0    223.0  11.5    68.0    9.0   30  2010    68
# 153         154   41.0    190.0   7.4    67.0    5.0    1  2010    67
# 154         155   30.0    193.0   6.9    70.0    9.0   26  2010    70
# 156         157   14.0    191.0  14.3    75.0    9.0   28  2010    75
# 157         158   18.0    131.0   8.0    76.0    9.0   29  2010    76
#
#      Weather_C  Weather_PS  Weather_S
# 0        False       False       True
# 1         True       False      False
# ...

# %%
data_cleaned4.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather_C     0
# Weather_PS    0
# Weather_S     0
# dtype: int64

# %%
# Normalization of the data

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
# we get in arrays of the dataframe with our col names
array = data_cleaned4.values
scaler = MinMaxScaler(feature_range =(0,1))
rescaledX = scaler.fit_transform(array)

# transform data
set_printoptions(precision = 2 )
print(rescaledX[0:5,:])
# Out:
# [[0.   0.24 0.56 0.28 0.25 0.   0.   0.   0.25 0.   0.   1.  ]
#  [0.01 0.21 0.34 0.31 0.38 0.   0.03 0.   0.38 1.   0.   0.  ]
#  [0.01 0.07 0.43 0.56 0.43 0.   0.07 0.   0.43 0.   1.   0.  ]
#  [0.02 0.1  0.94 0.5  0.12 0.   0.1  0.   0.12 0.   0.   1.  ]
#  [0.04 0.13 0.89 0.34 0.2  0.   0.2  0.   0.2  0.   1.   0.  ]]

# %%
#Standardize the data (0 mean , 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

#summarize transformed data
set_printoptions(precision =2)
print(rescaledX[0:5,:])
# Out:
# [[-1.84 -0.02  0.05 -0.71 -1.15 -1.53 -1.7   0.   -1.15 -0.64 -0.68  1.28]
#  [-1.82 -0.17 -0.75 -0.54 -0.62 -1.53 -1.59  0.   -0.62  1.57 -0.68 -0.78]
#  [-1.8  -0.9  -0.41  0.77 -0.4  -1.53 -1.48  0.   -0.4  -0.64  1.47 -0.78]
#  [-1.78 -0.72  1.43  0.45 -1.69 -1.53 -1.36  0.   -1.69 -0.64 -0.68  1.28]
#  [-1.71 -0.57  1.27 -0.37 -1.37 -1.53 -1.02  0.   -1.37 -0.64  1.47 -0.78]]

# %% [markdown]
#  speed up the EDA process

# %%
# !pip install ydata-profiling
# !pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 1.5 MB/s  0:00:05a 0:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.9/666.9 kB 874.4 kB/s  0:00:00981.6 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 1.1 MB/s  0:00:021.1 MB/s eta 0:00:01:010m
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.6
#     Uninstalling matplotlib-3.10.6:━━━━━━╺━━━━━━━━━━━━━━━━━━━  6/12 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.68;5;237m╺━━━━━━━━━━━━━━━━━━━  6/12 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [ydata-profiling] 11/12 [ydata-profiling]
# ...

# %%
import ydata_profiling as pp
import sweetviz as sv

# %%
EDA_report = pp.Profil eReport(data)
EDA_report.to_file(output_file='report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sweet_report = sv.analyze(data)
sweet_report.show_html('Weather_report.html')
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report Weather_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
