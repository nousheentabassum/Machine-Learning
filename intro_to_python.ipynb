# %%
print("hello")
# Out:
# hello

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# !pip install numpy

# %%
import numpy as np

# %%
df = pd.read_csv('/Users/furkhanansari/Desktop/Data Science/DataSets/Salaries.csv')

# %%
# list of first five records
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#attidubtes of Data frame
    #dtypes
    #columns
    #axes
    #ndim
    #size
    #shape
    #values

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df['rank'].dtype
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 468

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %%
#Data frame Methods
    #head
    #tail
    #describe
    #max
    #min
    #mean
    #median
    #std
    #sample
    #dropan

# %%
df.head(3)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515

# %%
df.tail(3)
# Out:
#     rank discipline  phd  service     sex  salary
# 75  Prof          B   17       17  Female  124312
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean(numeric_only = True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.std(numeric_only = True)
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df_50 = df.head(50)
df_50.mean(numeric_only = True)
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.head(50).mean(numeric_only =True)       #chaining of operations
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df['phd'].head(5)             #method 1 of selecting col
# Out:
# 0    56
# 1    12
# 2    23
# 3    40
# 4    20
# Name: phd, dtype: int64

# %%
df.phd.head(5)                #method 2 of selecting col
# Out:
# 0    56
# 1    12
# 2    23
# 3    40
# 4    20
# Name: phd, dtype: int64

# %%
df[['phd']].tail(5)       # method 3 of selecting col this give data in dataframe format
# Out:
#     phd
# 73   18
# 74   19
# 75   17
# 76   28
# 77   23

# %%
df.phd.mean()
# Out:
# np.float64(19.705128205128204)

# %%
df.phd.median()
# Out:
# 18.5

# %%
df.phd.mode()
# Out:
# 0    4
# Name: phd, dtype: int64

# %%
df[['phd']].describe()
# Out:
#              phd
# count  78.000000
# mean   19.705128
# std    12.498425
# min     1.000000
# 25%    10.250000
# 50%    18.500000
# 75%    27.750000
# max    56.000000

# %%
df.phd.size
# Out:
# 78

# %%
df.phd.count()
# Out:
# np.int64(78)

# %%
df_rank = df.groupby(['rank'])

# %%
df_rank.mean(numeric_only =True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df[df['salary'] < 120000]
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# ...

# %%
df[df['sex'] == 'Female'].count()
# Out:
# rank          39
# discipline    39
# phd           39
# service       39
# sex           39
# salary        39
# dtype: int64

# %%
df[['rank','salary']]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
# Slicing the DataFrame wiht iloc(integer location)
    # df.iloc[0] --> firstrow
    # df.iloc[-1] --> lastrow
    # df.iloc[row,col]
    # df.[start:stop-1,start:start-1]
    # df.iloc[[0,5],[1,3]]   list of rows , list of col

# %%
df.iloc[0]
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[0:7]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
df.iloc[:,[-1]]
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
df.iloc[:,0:4]
# Out:
#          rank discipline  phd  service
# 0        Prof          B   56       49
# 1        Prof          A   12        6
# 2        Prof          A   23       20
# 3        Prof          A   40       31
# 4        Prof          B   20       18
# ..        ...        ...  ...      ...
# 73       Prof          B   18       10
# 74  AssocProf          B   19        6
# 75       Prof          B   17       17
# 76       Prof          A   28       14
# 77       Prof          A   23       15
#
# [78 rows x 4 columns]

# %%
df.iloc[4:10,0:3]
# Out:
#         rank discipline  phd
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
df.iloc[[1,4,7,0],[3,4,1,0]]
# Out:
#    service   sex discipline  rank
# 1        6  Male          A  Prof
# 4       18  Male          B  Prof
# 7       18  Male          A  Prof
# 0       49  Male          B  Prof

# %%
df.iloc[0:11,0:4]
# Out:
#          rank discipline  phd  service
# 0        Prof          B   56       49
# 1        Prof          A   12        6
# 2        Prof          A   23       20
# 3        Prof          A   40       31
# 4        Prof          B   20       18
# 5        Prof          A   20       20
# 6   AssocProf          A   20       17
# 7        Prof          A   18       18
# 8        Prof          A   29       19
# 9        Prof          A   51       51
# 10       Prof          B   39       33

# %%
df.iloc[:,4:6]
# Out:
#        sex  salary
# 0     Male  186960
# 1     Male   93000
# 2     Male  110515
# 3     Male  131205
# 4     Male  104800
# ..     ...     ...
# 73  Female  105450
# 74  Female  104542
# 75  Female  124312
# 76  Female  109954
# 77  Female  109646
#
# [78 rows x 2 columns]

# %%
df.iloc[[59]]
# Out:
#          rank discipline  phd  service     sex  salary
# 59  AssocProf          B   12       10  Female  103994

# %%
df.iloc[[0,2],]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 2  Prof          A   23       20  Male  110515

# %%
# aggregate function
df[['phd','salary']].agg(['min','mean','max'])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# mean  19.705128  108023.782051
# max   56.000000  186960.000000

# %%
# basic discriptive statictics
    # df.describe
    # df.min
    # df.max
    # df.var
    # df.std
    # df.sem
    # df.skew
    # de.kurt

# %%
df['salary'].skew()
# Out:
# np.float64(0.45210256755588096)

# %%
df.phd.skew()
# Out:
# np.float64(0.6343660525514754)

# %%
df.phd.kurt()
# Out:
# np.float64(0.042503564567506036)
