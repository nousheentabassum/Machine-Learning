# %%
# !pip install matplotlib

# %%
# importing the dataset
import matplotlib.pyplot as plt

# %%
# matplotlib to render plots in the notebook
# %matplotlib inline

# %%
x = [-3,5,7]

# %%
y = [10,2,5]

# %%
fig = plt.figure(figsize=(15,3))
plt.plot(x,y)
plt.xlim(0,10)
plt.ylim(-3,8)
plt.xlabel('x axis')
plt.ylabel('y asis')
plt.title('line Plot')
plt.suptitle('sales comparision' , size = 20 , y =1.04)
# Out:
# Text(0.5, 1.04, 'sales comparision')

# %%
fig , ax = plt.subplots(nrows = 2 , ncols= 1)

# %%
fig , ax = plt.subplots(3,4)

# %%
# using data set for visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv('/Users/furkhanansari/Desktop/Data Science/DataSets/mtcars.csv')

# %%
cars.head(5)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
cars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
cars.shape
# Out:
# (32, 11)

# %%
cars.size
# Out:
# 352

# %%
cars.tail(5)
# Out:
#      mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  carb
# 27  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5     2
# 28  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5     4
# 29  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5     6
# 30  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5     8
# 31  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4     2

# %%
# creating the freq table for discreet vales
pd.crosstab(cars.gear,cars.cyl)
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
#creating bar plot between two variables in the dataset
pd.crosstab(cars.gear,cars.cyl).plot(kind="bar",ylabel = 'number of cars')
# Out:
# <Axes: xlabel='gear', ylabel='number of cars'>

# %%
cars['gear'].value_counts()
cars.gear.value_counts().plot(kind= "pie")
# Out:
# <Axes: ylabel='count'>

# %%
plt.scatter(cars.mpg,cars.qsec)  #scatter plot between two continious variables

# %%
plt.hist(cars.mpg)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(cars.disp , facecolor = "green" , edgecolor = 'yellow',bins=5)
# Out:
# (array([12.,  5.,  6.,  5.,  4.]),
#  array([ 71.1 , 151.28, 231.46, 311.64, 391.82, 472.  ]),
#  <BarContainer object of 5 artists>)

# %%
#box Plot
plt.boxplot(cars.mpg,vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16b9e2c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16b9e2e90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16b9e2ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16b9e3110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16b9e3250>],
#  'means': []}

# %%
plt.boxplot(cars.mpg, vert = False) 
plt.ylabel('MPG')
plt.xlabel("Boxplot")
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
#Voilin plot
plt.violinplot(cars.mpg)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x16aa25be0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x16aa25d30>,
#  'cmins': <matplotlib.collections.LineCollection at 0x16bba3ed0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x16bc18050>}
